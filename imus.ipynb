# %% [markdown]
# # Dataset description:

# %% [markdown]
# ### What is an IMU?
#
# An inertial measurement unit (IMU) measures and reports raw or filtered angular rate and specific force/acceleration experienced by the object it is attached to. Data outputs for an IMU are typically body-frame accelerations, angular rates, and (optionally) magnetic field measurements.

# %% [markdown]
# ### The columns of the dataset are:
#
# 1. Category: The category to which this IMU belongs.
#
# 2. Manufacturer: Name of the manufacturer.
#
# 3. part number: Discrete part number
#
# 4. sku: stock keeping unit
#
# 5. alt_sku: alternate stock keeping unit
#
# 6. Description: Description of the product
#
# 7. Status: Whether it is in stock or not
#
# 8. Quantity: Quantity available
#
# 9. Price: Price of the product
#
# 10. sku_create_date: when was the product procured

# %%
#Importing libraries

# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

# %%
df = pd.concat(pd.read_excel("D:/AI/Data science Bootcamp/Datasets/imus.xlsx", sheet_name=None), ignore_index=True)

# %%
df
# Out:
#          category                manufacturer part_number     sku alt_sku  \
# 0            1539  MS-OPEN VALUE SUBSCRIPTION   021-09108  BA0011     NaN
# 1            1539  MS-OPEN VALUE SUBSCRIPTION   059-07014  BA0025     NaN
# 2            1539  MS-OPEN VALUE SUBSCRIPTION   065-06444  BA0039     NaN
# 3            1539  MS-OPEN VALUE SUBSCRIPTION   076-04355  BA0067     NaN
# 4            1582  MS-OPEN VALUE SUBSCRIPTION   077-05318  BA0080     NaN
# ...           ...                         ...         ...     ...     ...
# 2627921      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627922      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627923      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627924      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627925      9945        VERBATIM CORPORATION       93975  986034     NaN
#
#                                                description    status  qty  \
# ...

# %%
df.to_csv ("imus.csv", index = None, header=True)

# %%
imus = pd.DataFrame(pd.read_csv("imus.csv"))

# %%
display(imus)
# Out:
#          category                manufacturer part_number     sku alt_sku  \
# 0            1539  MS-OPEN VALUE SUBSCRIPTION   021-09108  BA0011     NaN
# 1            1539  MS-OPEN VALUE SUBSCRIPTION   059-07014  BA0025     NaN
# 2            1539  MS-OPEN VALUE SUBSCRIPTION   065-06444  BA0039     NaN
# 3            1539  MS-OPEN VALUE SUBSCRIPTION   076-04355  BA0067     NaN
# 4            1582  MS-OPEN VALUE SUBSCRIPTION   077-05318  BA0080     NaN
# ...           ...                         ...         ...     ...     ...
# 2627921      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627922      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627923      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627924      9945        VERBATIM CORPORATION       93975  986034     NaN
# 2627925      9945        VERBATIM CORPORATION       93975  986034     NaN
#
#                                                description    status  qty  \
# ...

# %%
imus.head(10)
# Out:
#    category                manufacturer part_number     sku alt_sku  \
# 0      1539  MS-OPEN VALUE SUBSCRIPTION   021-09108  BA0011     NaN
# 1      1539  MS-OPEN VALUE SUBSCRIPTION   059-07014  BA0025     NaN
# 2      1539  MS-OPEN VALUE SUBSCRIPTION   065-06444  BA0039     NaN
# 3      1539  MS-OPEN VALUE SUBSCRIPTION   076-04355  BA0067     NaN
# 4      1582  MS-OPEN VALUE SUBSCRIPTION   077-05318  BA0080     NaN
# 5      1539  MS-OPEN VALUE SUBSCRIPTION   079-04668  BA0095     NaN
# 6      1539  MS-OPEN VALUE SUBSCRIPTION   125-00511  BA0224     NaN
# 7      1539  MS-OPEN VALUE SUBSCRIPTION   126-01023  BA0249     NaN
# 8      1539  MS-OPEN VALUE SUBSCRIPTION   126-01024  BA0250     NaN
# 9      1539  MS-OPEN VALUE SUBSCRIPTION   164-05581  BA0291     NaN
#
#                                          description    status  qty   price  \
# 0               1YR OFFICESTD ALNG LICSAPK OLV, D AP  No Stock    0  143.58
# ...

# %% [markdown]
# # In Stock

# %%
#Seperating products which are in stock

# %%
in_stock = imus[imus.status == 'In Stock']
display(in_stock)
# Out:
#          category                    manufacturer         part_number     sku  \
# 253          9920  CASE LOGIC-PERSONAL & PORTABLE             3200943  BA6371
# 271           531                OMNITRON SYSTEMS              7206-0  BA6834
# 320          9070         ZEBRA ENTERPRISE MCD-A1       SAC5070-800CR  BC0227
# 324          9080         ZEBRA ENTERPRISE MCD-A1  KT-CLMPT-RS507-01R  BC0232
# 326          9080         ZEBRA ENTERPRISE MCD-A1    KT-PAD-RS507-10R  BC0234
# ...           ...                             ...                 ...     ...
# 2627921      9945            VERBATIM CORPORATION               93975  986034
# 2627922      9945            VERBATIM CORPORATION               93975  986034
# 2627923      9945            VERBATIM CORPORATION               93975  986034
# 2627924      9945            VERBATIM CORPORATION               93975  986034
# 2627925      9945            VERBATIM CORPORATION               93975  986034
#
# ...

# %% [markdown]
# ### 1. Which are the top Manufacturers with price, quantity?

# %%
#Making new coloum of networth

in_stock['networth'] = in_stock.qty*in_stock.price
# Out:
# C:\Users\Rhytham\AppData\Local\Temp/ipykernel_13324/699994252.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_stock['networth'] = in_stock.qty*in_stock.price

# %%
in_stock.sort_values("networth", ascending=False).head()
# Out:
#          category                 manufacturer part_number     sku alt_sku  \
# 2502762      1221          DELL ESG WARRANTIES    823-7912  7GZ792     NaN
# 1890636      1221  DELL CSG SERVICE WARRANTIES    818-6447  3DB700     NaN
# 625985       1221  DELL CSG SERVICE WARRANTIES    818-6447  3DB700     NaN
# 2450786      1221  DELL CSG SERVICE WARRANTIES    818-6447  3DB700     NaN
# 2502761      1221          DELL ESG WARRANTIES    823-7911  7GZ791     NaN
#
#                        description    status   qty    price sku_create_date  \
# 2502762  3YR NBD TO 5YR PROSPT 4H,  In Stock  9999  4236.30      2020-08-26
# 1890636       5YR PROSUPPORT PLUS,  In Stock  9999  3800.72      2020-08-24
# 625985        5YR PROSUPPORT PLUS,  In Stock  9999  3800.72      2020-08-17
# 2450786       5YR PROSUPPORT PLUS,  In Stock  9999  3798.68      2020-08-26
# 2502761  3YR NBD TO 5YR PROSPT 4H,  In Stock  9999  3111.01      2020-08-26
#
#             networth
# 2502762  42358763.70
# ...

# %% [markdown]
# ##### Above given are the top Manufacturers with price, quantity

# %% [markdown]
# ### 2. Which are the most profitable products?

# %% [markdown]
# According to me the most profitable product will be the one whose price is high as well as at the same time the quantiy is more,as if the price is higher we will get good margin in that and as the quantity is more we will be having more stock of that product so it will be more profitable

# %%
in_stock[in_stock.networth == in_stock.networth.max()]
# Out:
#          category         manufacturer part_number     sku alt_sku  \
# 2502762      1221  DELL ESG WARRANTIES    823-7912  7GZ792     NaN
#
#                        description    status   qty   price sku_create_date  \
# 2502762  3YR NBD TO 5YR PROSPT 4H,  In Stock  9999  4236.3      2020-08-26
#
#            networth
# 2502762  42358763.7

# %% [markdown]
# #####  Above given the most profitable products

# %% [markdown]
# ### 3. Which is the product where you have seen a decrease in the price?

# %%
prod = in_stock.sort_values("networth", ascending=True).head(50)

# %%
prod
# Out:
#          category             manufacturer       part_number     sku alt_sku  \
# 1287202      1251                 CONFIG 1  SCX-5835FN - TAA  CX4513     NaN
# 1287203      1251                 CONFIG 1    BTRY-MC55EAB00  CX4544     NaN
# 21676        1251                 CONFIG 1  SCX-5835FN - TAA  CX4513     NaN
# 21677        1251                 CONFIG 1    BTRY-MC55EAB00  CX4544     NaN
# 233062       2250    BLACK BOX CORPORATION             SMH-1  TT2632     NaN
# 1317452      1022      ENERGIZER-BATTERIES            389BPZ  GE5467     NaN
# 51995        1022      ENERGIZER-BATTERIES            389BPZ  GE5467     NaN
# 1321908      2240            C2G - AV LINE             01927  GU6630     NaN
# 1321910      2240            C2G - AV LINE             01927  GU6630     NaN
# 1321918      2240            C2G - AV LINE             01927  GU6630     NaN
# 1321917      2240            C2G - AV LINE             01927  GU6630     NaN
# ...

# %%
ax = sns.barplot(x='networth', y='description', data=prod)
yscale = 'log'
ax.set(xlabel='Price', ylabel='Product', title='Finding decrease in the price')
# Out:
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Product'),
#  Text(0.5, 1.0, 'Finding decrease in the price')]

# %% [markdown]
# ###### As we can see from the upper chart, SURFACE-MOUNT HOUSING 1-PORT WH, ITE  have seen an decrease in the price.

# %% [markdown]
# ### 4. Which is the product where you have seen an increase in the price?

# %%
prod_inc = in_stock.sort_values("networth", ascending=False).head(50)

# %%
prod_inc
# Out:
#          category                 manufacturer           part_number     sku  \
# 2502762      1221          DELL ESG WARRANTIES              823-7912  7GZ792
# 1890636      1221  DELL CSG SERVICE WARRANTIES              818-6447  3DB700
# 625985       1221  DELL CSG SERVICE WARRANTIES              818-6447  3DB700
# 2450786      1221  DELL CSG SERVICE WARRANTIES              818-6447  3DB700
# 2502761      1221          DELL ESG WARRANTIES              823-7911  7GZ791
# 2450785      1221          DELL ESG WARRANTIES              818-6446  3DB699
# 1890635      1221          DELL ESG WARRANTIES              818-6446  3DB699
# 625984       1221          DELL ESG WARRANTIES              818-6446  3DB699
# 2450784      1221          DELL ESG WARRANTIES              818-6445  3DB698
# 1664364      1251  IM CHOICE ADVANTAGE - GOVED               FEDADV1  ZM9366
# 399288       1251  IM CHOICE ADVANTAGE - GOVED               FEDADV1  ZM9366
# ...

# %%
ax = sns.barplot(x='networth', y='description', data=prod_inc)
xscale = 'log'
ax.set(xlabel='Price', ylabel='Product', title='Finding increase in the price')
# Out:
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Product'),
#  Text(0.5, 1.0, 'Finding increase in the price')]

# %% [markdown]
# ###### As we can see from the upper chart, 3YR NBD TO 5YR PROSPT 4H have seen an increase in the price.

# %% [markdown]
# ### 5. Which is the top category by price and quantity?

# %% [markdown]
# ##### Finding catagory top by Quantity

# %%
in_stock[in_stock.qty == in_stock.qty.max()]
# Out:
#          category                 manufacturer part_number     sku alt_sku  \
# 2364017      1221  DELL CSG SERVICE WARRANTIES    808-3177  4A1885     NaN
#
#                                  description    status    qty  price  \
# 2364017  3YR NBD TO 3YR PROSUP NBD, OPTIPLEX  In Stock  60063  38.76
#
#         sku_create_date    networth
# 2364017      2020-08-25  2328041.88

# %% [markdown]
# ##### Finding catagory top by price

# %%
in_stock[in_stock.price == in_stock.price.max()]
# Out:
#          category     manufacturer part_number     sku alt_sku  \
# 1199874       521  HPE - SWITCHING  JL376A#B2B  6RN996     NaN
#
#                                                description    status  qty  \
# 1199874  ARUBA 8400 1 MM 3 PS 2 FM 32/8, BDL JMPCBL-NA/...  In Stock    3
#
#             price sku_create_date   networth
# 1199874  69729.03      2020-08-20  209187.09

# %% [markdown]
# ### 6. Which products are aging?

# %%
# Here the peoducts which have the more quantity can be considered as the as product aging
#Because having more product can be considered as they are not getting sold

# %%
in_stock.sort_values("qty", ascending=False).head()
# Out:
#          category                 manufacturer part_number     sku alt_sku  \
# 2364017      1221  DELL CSG SERVICE WARRANTIES    808-3177  4A1885     NaN
# 1135792      1221  DELL CSG SERVICE WARRANTIES    808-3123  4A1836     NaN
# 2609950      1221  DELL CSG SERVICE WARRANTIES    808-3108  4A1821     NaN
# 1245234      1221  DELL CSG SERVICE WARRANTIES    808-3105  4A1818     NaN
# 2558454      1221  DELL CSG SERVICE WARRANTIES    808-3105  4A1818     NaN
#
#                                                description    status    qty  \
# 2364017                3YR NBD TO 3YR PROSUP NBD, OPTIPLEX  In Stock  60063
# 1135792  1YR HW SVC WITH IN-HOME/OS SVC, AFTER REM DIAG...  In Stock  60018
# 2609950  1YR HW SVC WITH IN-HOME/OS SVC, AFTER REM DIAG...  In Stock  60014
# 1245234  1YR HW SVC WITH IN-HOME/OS SVC, AFTER REM DIAG...  In Stock  60005
# 2558454  1YR HW SVC WITH IN-HOME/OS SVC, AFTER REM DIAG...  In Stock  60004
#
#           price sku_create_date    networth
# ...

# %% [markdown]
# ### 7. How to Decrease Product aging?

# %% [markdown]
# One thing we can do to decrease product aging is that, we can create a  discounted price of that product,the discount will be in such a way that is a customer buys that product in bulk quantity then the price will be reduced
# Or one more thing we can do is to offer  the customer buy 3 get 1 free deal or something like that....doing this will sell most of our products and there will be no loss of manufacturer

# %%
'''For Example if we are offering buy 3 get 1 free, then the average discount on per product will be 33.3%'''
# Out:
# 'For Example if we are offering buy 3 get 1 free, then the average discount on per product will be 33.3%'

# %%
in_stock['discounted_price'] = in_stock.price*66.7/100
# Out:
# C:\Users\Rhytham\AppData\Local\Temp/ipykernel_13324/2648462530.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   in_stock['discounted_price'] = in_stock.price*66.7/100

# %%
display(in_stock)
# Out:
#          category                    manufacturer         part_number     sku  \
# 253          9920  CASE LOGIC-PERSONAL & PORTABLE             3200943  BA6371
# 271           531                OMNITRON SYSTEMS              7206-0  BA6834
# 320          9070         ZEBRA ENTERPRISE MCD-A1       SAC5070-800CR  BC0227
# 324          9080         ZEBRA ENTERPRISE MCD-A1  KT-CLMPT-RS507-01R  BC0232
# 326          9080         ZEBRA ENTERPRISE MCD-A1    KT-PAD-RS507-10R  BC0234
# ...           ...                             ...                 ...     ...
# 2627921      9945            VERBATIM CORPORATION               93975  986034
# 2627922      9945            VERBATIM CORPORATION               93975  986034
# 2627923      9945            VERBATIM CORPORATION               93975  986034
# 2627924      9945            VERBATIM CORPORATION               93975  986034
# 2627925      9945            VERBATIM CORPORATION               93975  986034
#
# ...

# %% [markdown]
# ##### Above given are containing the coloum of discounted price

# %% [markdown]
# # Not In Stock

# %%
#Seperating products which are in stock

# %%
no_stock = imus[imus.status == 'No Stock']
display(no_stock)
# Out:
#          category                manufacturer     part_number     sku alt_sku  \
# 0            1539  MS-OPEN VALUE SUBSCRIPTION       021-09108  BA0011     NaN
# 1            1539  MS-OPEN VALUE SUBSCRIPTION       059-07014  BA0025     NaN
# 2            1539  MS-OPEN VALUE SUBSCRIPTION       065-06444  BA0039     NaN
# 3            1539  MS-OPEN VALUE SUBSCRIPTION       076-04355  BA0067     NaN
# 4            1582  MS-OPEN VALUE SUBSCRIPTION       077-05318  BA0080     NaN
# ...           ...                         ...             ...     ...     ...
# 2627418      3360                      TARGUS        AMB580TT  9X4546     NaN
# 2627775       505                    ENGENIUS         EAP1300  9Z0170     NaN
# 2627822      9910                    KINGSTON      HX-MPFS-SM  9Z6619     NaN
# 2627853       291   KINGSTON TECHNOLOGY FLASH  SD10VG2/16GBCP  9Z8507     NaN
# 2627857       291                    KINGSTON     IKD300S/4GB  9103LA     NaN
#
# ...

# %% [markdown]
# ### 1. Which are the top Manufacturers with price, quantity?

# %% [markdown]
# As we are talking about the data which are not in stock we are not supposed to know the manufacturer who's quantity is on top but surely we can know the price which is on top

# %%
no_stock.sort_values("price", ascending=False).head()
# Out:
#          category          manufacturer         part_number     sku alt_sku  \
# 1046052      1231                ALTNET   ALT-TPM-240000000  6QN385     NaN
# 2310142      1231                ALTNET   ALT-TPM-240000000  6QN385     NaN
# 1046051      1231                ALTNET    ALT-TPM-80000000  6QN384     NaN
# 2310141      1231                ALTNET    ALT-TPM-80000000  6QN384     NaN
# 973610       1241  JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451     NaN
#
#                                                description    status  qty  \
# 1046052  ALTNET TPM UP TO 240000000 USD, LIST MNT UPTO ...  No Stock    0
# 2310142  ALTNET TPM UP TO 240000000 USD, LIST MNT UPTO ...  No Stock    0
# 1046051  ALTNET TPM UP TO 80000000 USD, LIST MNT UPTO 8...  No Stock    0
# 2310141  ALTNET TPM UP TO 80000000 USD, LIST MNT UPTO 8...  No Stock    0
# 973610                   ROW 5YR SWA SUP FOR, JCE-1000GBPS  No Stock    0
#
#                price sku_create_date
# ...

# %% [markdown]
# ##### Above given are the top Manufacturers with price, quantity

# %% [markdown]
# ### 2. Which are the most profitable products?

# %%
no_stock[no_stock.price == no_stock.price.max()]
# Out:
#          category manufacturer        part_number     sku alt_sku  \
# 1046052      1231       ALTNET  ALT-TPM-240000000  6QN385     NaN
# 2310142      1231       ALTNET  ALT-TPM-240000000  6QN385     NaN
#
#                                                description    status  qty  \
# 1046052  ALTNET TPM UP TO 240000000 USD, LIST MNT UPTO ...  No Stock    0
# 2310142  ALTNET TPM UP TO 240000000 USD, LIST MNT UPTO ...  No Stock    0
#
#               price sku_create_date
# 1046052  84974533.1      2020-08-17
# 2310142  84974533.1      2020-08-24

# %% [markdown]
# #####  Above given the most profitable products

# %% [markdown]
# ### 3. Which is the product where you have seen a decrease in the price?

# %%
non_zero = no_stock[no_stock['price'] > 0]
no_prod = non_zero.sort_values("price", ascending=True).head(10)

# %%
no_prod
# Out:
#          category          manufacturer           part_number     sku alt_sku  \
# 1771941      1569        FORCEPOINT MSP  MFPURL2MO-0-CP12-X-N  2MM574     NaN
# 997504       1569   FORCEPOINT SERVICES     DLPEIP-3-CP62-P-R  6KG047     NaN
# 912255       1241    IBM - POWER SYSTEM         9117-MMD-EB73  6CP813     NaN
# 912256       1241    IBM - POWER SYSTEM         9117-MMU-EB73  6CP814     NaN
# 912257       1241    IBM - POWER SYSTEM         9117-MMC-EB73  6CP815     NaN
# 997503       1241    FORCEPOINT SUPPORT     ESESPT-3-CP62-P-R  6KG046     NaN
# 997502       1569   FORCEPOINT SERVICES     DLPNIP-3-CP62-P-R  6KG045     NaN
# 997501       1241    FORCEPOINT SUPPORT     ESESPT-3-CP62-P-R  6KG044     NaN
# 997500       1569   FORCEPOINT SERVICES     DLPDIP-3-CP62-P-R  6KG043     NaN
# 997485       1241  JUNIPER PAR SERVICES      PAR-SUP-MX204-IR  6KG018     NaN
#
#                                                description    status  qty  \
# ...

# %%
ax = sns.barplot(x='price', y='description', data=no_prod)
xscale = 'log'
ax.set(xlabel='Price', ylabel='Product', title='Finding decrease in the price')
# Out:
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Product'),
#  Text(0.5, 1.0, 'Finding decrease in the price')]

# %% [markdown]
# ###### Here Above given products have the leastest price among all the products

# %% [markdown]
# ### 4. Which is the product where you have seen an increase in the price?

# %%
no_prod_in = no_stock.sort_values("price", ascending=False).head(10)

# %%
no_prod_in
# Out:
#          category                manufacturer         part_number     sku  \
# 1046052      1231                      ALTNET   ALT-TPM-240000000  6QN385
# 2310142      1231                      ALTNET   ALT-TPM-240000000  6QN385
# 1046051      1231                      ALTNET    ALT-TPM-80000000  6QN384
# 2310141      1231                      ALTNET    ALT-TPM-80000000  6QN384
# 973610       1241        JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451
# 2237750      1241        JUNIPER ROW SERVICES  SV5-SWA-JCE-1KGBPS  6JB451
# 973606       1241        JUNIPER ROW SERVICES  SV3-SWA-JCE-1KGBPS  6JB398
# 2237746      1241        JUNIPER ROW SERVICES  SV3-SWA-JCE-1KGBPS  6JB398
# 2261823      1241  JUNIPER ENTERPRISE ROUTING  QSFP-100G-LR4-1000  6KG376
# 997704       1241  JUNIPER ENTERPRISE ROUTING  QSFP-100G-LR4-1000  6KG376
#
#         alt_sku                                        description    status  \
# ...

# %%
ax = sns.barplot(x='price', y='description', data=no_prod_in)
xscale = 'log'
ax.set(xlabel='Price', ylabel='Product', title='Finding increase in the price')
# Out:
# [Text(0.5, 0, 'Price'),
#  Text(0, 0.5, 'Product'),
#  Text(0.5, 1.0, 'Finding increase in the price')]

# %% [markdown]
# ###### As we can see from the upper chart, ALTNET   have seen an increase in the price.

# %% [markdown]
# ### 5. Which is the top category by price and quantity?

# %% [markdown]
# ##### Finding catagory top by price

# %%
no_stock[no_stock.price == no_stock.price.max()]
# Out:
#          category manufacturer        part_number     sku alt_sku  \
# 1046052      1231       ALTNET  ALT-TPM-240000000  6QN385     NaN
# 2310142      1231       ALTNET  ALT-TPM-240000000  6QN385     NaN
#
#                                                description    status  qty  \
# 1046052  ALTNET TPM UP TO 240000000 USD, LIST MNT UPTO ...  No Stock    0
# 2310142  ALTNET TPM UP TO 240000000 USD, LIST MNT UPTO ...  No Stock    0
#
#               price sku_create_date
# 1046052  84974533.1      2020-08-17
# 2310142  84974533.1      2020-08-24
